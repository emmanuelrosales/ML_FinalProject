# %% [markdown]
# # Instituto Tecnológico de Costa Rica
#
# ### Escuela de Ingeniería en Computación
#
# ### Maestría Académica en Ciencias de la Computación
#
# ### Curso: Aprendizaje Automático (Machine Learning)
#
# # Proyecto Final
# - Multivariate Exogenous Time Series Modeling for Real-Time Pump Pressure Forecasting
# ## Estudiantes:
# - Emmanuel Rosales Salas - 2013108931
# - Alejandro Arroyo Valle - 2016108971

# %% [markdown]
# # Carga de Bibliotecas y Dataset

# %% [markdown]
# ## Instalar las bibliotecas necesarias

# %%
# %pip install -q numpy pandas matplotlib seaborn scikit-learn statsmodels pmdarima xgboost lightgbm
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importación de la clases

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sklearn.preprocessing import RobustScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
#from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.feature_selection import mutual_info_regression
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# ## Importar los datos.

# %%
raw_dataset = pd.read_csv('multi_data_01.csv', header = 0, parse_dates = [0], index_col = 0)

## Algunos datos estan desordenados, los ordenamos por fecha
raw_dataset = raw_dataset.sort_index()

## Para pruenas, reducir el tamaÑo del dataset
lite_size = int(len(raw_dataset) * 0.4)
raw_dataset = raw_dataset.iloc[:lite_size]

raw_dataset.head()
# Out:
#                            runautomode_bool  actual_speed_m_min  \
# date_time
# 2023-06-22 14:16:06.761126                t                 3.5
# 2023-06-22 14:16:12.104136                t                 3.5
# 2023-06-22 14:16:17.457427                t                 3.5
# 2023-06-22 14:16:25.906595                t                 3.5
# 2023-06-22 14:16:33.827435                t                 3.5
#
#                             secundary_pumpspeed_rpm  secundary_pa16d1_bar  \
# date_time
# 2023-06-22 14:16:06.761126                21.589945             33.216620
# 2023-06-22 14:16:12.104136                21.516739             33.197170
# 2023-06-22 14:16:17.457427                21.919836             33.122610
# 2023-06-22 14:16:25.906595                21.708180             33.070736
# 2023-06-22 14:16:33.827435                21.853577             33.161510
#
#                             secundary_p014d1_bar  secundary_p015d1_bar  \
# date_time
# 2023-06-22 14:16:06.761126              94.21156             57.346170
# 2023-06-22 14:16:12.104136              94.46119             57.368862
# 2023-06-22 14:16:17.457427              94.12079             57.312130
# 2023-06-22 14:16:25.906595              94.32503             57.266743
# 2023-06-22 14:16:33.827435              94.35907             57.391556
#
#                             secundary_pa7b3_mm  secundary_pa4b2_c  \
# date_time
# 2023-06-22 14:16:06.761126           34.467407               99.9
# 2023-06-22 14:16:12.104136           34.337220               99.9
# 2023-06-22 14:16:17.457427           34.402344               99.9
# 2023-06-22 14:16:25.906595           34.272156               99.9
# 2023-06-22 14:16:33.827435           34.239563               99.9
#
#                             secundary_pa4b5_c  secundary_pu2b2_c  ...  \
# date_time                                                         ...
# 2023-06-22 14:16:06.761126              103.2               99.8  ...
# 2023-06-22 14:16:12.104136              103.2               99.8  ...
# 2023-06-22 14:16:17.457427              103.1               99.8  ...
# 2023-06-22 14:16:25.906595              103.1               99.8  ...
# 2023-06-22 14:16:33.827435              103.1               99.8  ...
#
#                             primary_p015d1_bar  primary_pa7b3_mm  \
# date_time
# 2023-06-22 14:16:06.761126           78.950264         225.65234
# 2023-06-22 14:16:12.104136           75.478180         226.00946
# 2023-06-22 14:16:17.457427           81.038055         225.94452
# 2023-06-22 14:16:25.906595           79.222590         225.84710
# 2023-06-22 14:16:33.827435           75.841270         225.42505
#
#                             primary_pa4b2_c  primary_pa4b5_c  primary_pu2b2_c  \
# date_time
# 2023-06-22 14:16:06.761126            102.0             99.7            100.4
# 2023-06-22 14:16:12.104136            101.9             99.7            100.4
# 2023-06-22 14:16:17.457427            101.8             99.7            100.4
# 2023-06-22 14:16:25.906595            101.7             99.9            100.2
# 2023-06-22 14:16:33.827435            101.6             99.9            100.2
#
#                             primary_p012b3_c  primary_p022b3_c  \
# date_time
# 2023-06-22 14:16:06.761126              86.9             100.2
# 2023-06-22 14:16:12.104136              86.8             100.1
# 2023-06-22 14:16:17.457427              86.4             100.2
# 2023-06-22 14:16:25.906595              86.9             100.2
# 2023-06-22 14:16:33.827435              86.9             100.2
#
#                             primary_pa16d6_c  primary_p014d6_c  \
# date_time
# 2023-06-22 14:16:06.761126             869.9             100.2
# 2023-06-22 14:16:12.104136             869.9             100.1
# 2023-06-22 14:16:17.457427             869.9             100.0
# 2023-06-22 14:16:25.906595             869.9              99.9
# 2023-06-22 14:16:33.827435             869.9              99.8
#
#                             primary_p015d6_c
# date_time
# 2023-06-22 14:16:06.761126             105.3
# 2023-06-22 14:16:12.104136             105.1
# 2023-06-22 14:16:17.457427             105.1
# 2023-06-22 14:16:25.906595             104.8
# 2023-06-22 14:16:33.827435             104.6
#
# [5 rows x 29 columns]

# %% [markdown]
# # Exploración de Datos

# %% [markdown]
# ## Contexto de los datos

# %% [markdown]
# ![Texto alternativo](image005.png)
# ![Texto alternativo](drum_press.jpg)

# %% [markdown]
# Este dataset contiene datos de dos máquinas de producción, estas máquinas son prensas hidráulicas que bombean material adhesivo sobre una lámina plástica, similares a la imagen anterior. Además del timestamp, las columnas representan valores de diferentes sensores que tiene cada prensa.
#
# En el nombre de cada columna hay un sufijo que describe si el valor corresponde a la prensa "secundary" o "primary". Después de este sufijo, se especifíca el nombre del sensor que está siendo leído, finalmente los nombres de las columnas termina con la unidad de la variable en cuestión.
#
# El nombre del sensor se puede referenciar en la primer imagen.

# %%
print("Descripción del Dataset");
raw_dataset.describe()
# Out:
# Descripción del Dataset
#        actual_speed_m_min  secundary_pumpspeed_rpm  secundary_pa16d1_bar  \
# count       375912.000000            375912.000000         375912.000000
# mean             3.871782                34.593661             27.679514
# std              3.121010                26.956397              9.830933
# min              0.000000                 0.000000              1.455618
# 25%              0.000000                 0.982634             29.251766
# 50%              5.000000                41.446367             30.162743
# 75%              6.500000                54.599004             32.723854
# max              7.899999               100.000000             38.902935
#
#        secundary_p014d1_bar  secundary_p015d1_bar  secundary_pa7b3_mm  \
# count         375912.000000         375912.000000       375912.000000
# mean              92.020630             56.156945          287.969290
# std               55.664310             40.397132          168.549777
# min                1.066589             -1.157362            6.509399
# 25%               29.864487              5.537184          148.577700
# 50%              122.748490             78.326195          286.642730
# 75%              140.835110             92.112430          431.347350
# max              295.104700            277.052120          730.227840
#
#        secundary_pa4b2_c  secundary_pa4b5_c  secundary_pu2b2_c  \
# count      375912.000000      375912.000000      375912.000000
# mean           95.423379          99.041047          94.336670
# std            14.446986          15.151891          15.133108
# min            29.400000          29.900000          29.400000
# 25%            99.800000         103.000000          99.800000
# 50%            99.900000         103.500000          99.900000
# 75%           100.100000         103.800000         100.100000
# max           101.300000         105.600000         102.200000
#
#        secundary_p012b3_c  ...  primary_p015d1_bar  primary_pa7b3_mm  \
# count       375912.000000  ...       375912.000000     375912.000000
# mean            85.152146  ...           73.798730        365.606005
# std             21.937484  ...           46.335902        209.045954
# min             27.100000  ...           -1.327563          2.240234
# 25%             86.100000  ...           25.348505        194.645390
# 50%             94.300000  ...           97.672300        363.576230
# 75%             97.200000  ...          112.309530        521.662700
# max            104.700000  ...          371.796970        976.928500
#
#        primary_pa4b2_c  primary_pa4b5_c  primary_pu2b2_c  primary_p012b3_c  \
# count    375912.000000    375912.000000    375912.000000      375912.00000
# mean         99.890166        96.587912        96.404204          83.63529
# std          23.641361        15.535693        15.706319          19.57291
# min        -200.000000        41.500000        40.600000          24.10000
# 25%         102.100000        99.700000        99.700000          83.60000
# 50%         104.200000        99.900000        99.900000          86.00000
# 75%         105.200000       100.100000       100.200000          88.70000
# max         869.900000       869.900000       869.900000         869.90000
#
#        primary_p022b3_c  primary_pa16d6_c  primary_p014d6_c  primary_p015d6_c
# count     375912.000000      3.759120e+05     375912.000000     375912.000000
# mean          93.530312      8.699000e+02         93.674378        440.780309
# std           17.068429      2.273740e-13         12.143941        324.640172
# min           23.500000      8.699000e+02         38.300000         26.900000
# 25%           99.600000      8.699000e+02         93.600000        112.300000
# 50%           99.900000      8.699000e+02         96.700000        359.200000
# 75%          100.200000      8.699000e+02         99.700000        869.900000
# max          103.300000      8.699000e+02        118.800000        869.900000
#
# [8 rows x 28 columns]

# %%
print(f"Las dimensiones del dataset son (filas, columnas): {raw_dataset.shape}")
# Out:
# Las dimensiones del dataset son (filas, columnas): (375912, 29)

# %%
raw_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 375912 entries, 2023-06-22 14:16:06.761126 to 2023-07-14 17:23:59.251937
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   runautomode_bool             375912 non-null  object
#  1   actual_speed_m_min           375912 non-null  float64
#  2   secundary_pumpspeed_rpm      375912 non-null  float64
#  3   secundary_pa16d1_bar         375912 non-null  float64
#  4   secundary_p014d1_bar         375912 non-null  float64
#  5   secundary_p015d1_bar         375912 non-null  float64
#  6   secundary_pa7b3_mm           375912 non-null  float64
#  7   secundary_pa4b2_c            375912 non-null  float64
#  8   secundary_pa4b5_c            375912 non-null  float64
#  9   secundary_pu2b2_c            375912 non-null  float64
#  10  secundary_p012b3_c           375912 non-null  float64
#  11  secundary_p022b3_c           375912 non-null  float64
#  12  secundary_pa16d6_c           375912 non-null  float64
#  13  secundary_p014d6_c           375912 non-null  float64
#  14  secundary_p015d6_c           375912 non-null  float64
#  15  secundary_multipressure_bar  375912 non-null  float64
#  16  primary_pumpspeed_rpm        375912 non-null  float64
#  17  primary_pa16d1_bar           375912 non-null  float64
#  18  primary_p014d1_bar           375912 non-null  float64
#  19  primary_p015d1_bar           375912 non-null  float64
#  20  primary_pa7b3_mm             375912 non-null  float64
#  21  primary_pa4b2_c              375912 non-null  float64
#  22  primary_pa4b5_c              375912 non-null  float64
#  23  primary_pu2b2_c              375912 non-null  float64
#  24  primary_p012b3_c             375912 non-null  float64
#  25  primary_p022b3_c             375912 non-null  float64
#  26  primary_pa16d6_c             375912 non-null  float64
#  27  primary_p014d6_c             375912 non-null  float64
#  28  primary_p015d6_c             375912 non-null  float64
# dtypes: float64(28), object(1)
# memory usage: 86.0+ MB

# %% [markdown]
# ## Gráficos

# %%
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (15, 7) # Aumentar el tamaño del gráfico

raw_dataset['secundary_multipressure_bar'].plot()

# Añadir títulos y etiquetas para mayor claridad
plt.title('Evolución de Secundary Multipressure Bar a lo Largo del Tiempo', fontsize=16)
plt.xlabel('Fecha', fontsize=12)
plt.ylabel('Secundary Multipressure Bar', fontsize=12)
plt.show()

# %%
raw_dataset['secundary_multipressure_bar'].plot(kind='hist', bins=30, title='Distribución de Frecuencias de Secundary Multipressure Bar')
plt.xlabel('Secundary Multipressure Bar')
plt.show()

# %%
sns.boxplot(x=raw_dataset['secundary_multipressure_bar'])
plt.title('Boxplot Secundary Multipressure Bar')
plt.show()

# %% [markdown]
# # Preprocesamiento de Datos

# %% [markdown]
# ## Eliminación de las columnas primary
#
# Dada la naturaleza de nuestro proyecto, queremos predecir la variable secundary_multipressure_bar, por esta razón, todas las caracterísiticas que influyen en ella son las que tienen como pre fijos "secundary". Por esta razón, las columnas que son de primary, no son necesarias para nuestra predicción, por lo tanto procedemos a eliminarlas.

# %%
# Eliminar las columnas relacionadas con primary

# Primero se obtienen los nombres de las columnas que contienen 'primary'
primary_columns = raw_dataset.filter(like = 'primary').columns

# Eliminamos las columnas del DataFrame
processed_dataset = raw_dataset.drop(columns = primary_columns)

# Imprimir la cantidad de columnas eliminadas y las primeras filas del nuevo DataFrame
print("\nDataFrame después de eliminar las columnas:")
print(f"Se eliminaron {len(primary_columns)}")
processed_dataset.head()
# Out:
# DataFrame después de eliminar las columnas:
# Se eliminaron 13
#                            runautomode_bool  actual_speed_m_min  \
# date_time
# 2023-06-22 14:16:06.761126                t                 3.5
# 2023-06-22 14:16:12.104136                t                 3.5
# 2023-06-22 14:16:17.457427                t                 3.5
# 2023-06-22 14:16:25.906595                t                 3.5
# 2023-06-22 14:16:33.827435                t                 3.5
#
#                             secundary_pumpspeed_rpm  secundary_pa16d1_bar  \
# date_time
# 2023-06-22 14:16:06.761126                21.589945             33.216620
# 2023-06-22 14:16:12.104136                21.516739             33.197170
# 2023-06-22 14:16:17.457427                21.919836             33.122610
# 2023-06-22 14:16:25.906595                21.708180             33.070736
# 2023-06-22 14:16:33.827435                21.853577             33.161510
#
#                             secundary_p014d1_bar  secundary_p015d1_bar  \
# date_time
# 2023-06-22 14:16:06.761126              94.21156             57.346170
# 2023-06-22 14:16:12.104136              94.46119             57.368862
# 2023-06-22 14:16:17.457427              94.12079             57.312130
# 2023-06-22 14:16:25.906595              94.32503             57.266743
# 2023-06-22 14:16:33.827435              94.35907             57.391556
#
#                             secundary_pa7b3_mm  secundary_pa4b2_c  \
# date_time
# 2023-06-22 14:16:06.761126           34.467407               99.9
# 2023-06-22 14:16:12.104136           34.337220               99.9
# 2023-06-22 14:16:17.457427           34.402344               99.9
# 2023-06-22 14:16:25.906595           34.272156               99.9
# 2023-06-22 14:16:33.827435           34.239563               99.9
#
#                             secundary_pa4b5_c  secundary_pu2b2_c  \
# date_time
# 2023-06-22 14:16:06.761126              103.2               99.8
# 2023-06-22 14:16:12.104136              103.2               99.8
# 2023-06-22 14:16:17.457427              103.1               99.8
# 2023-06-22 14:16:25.906595              103.1               99.8
# 2023-06-22 14:16:33.827435              103.1               99.8
#
#                             secundary_p012b3_c  secundary_p022b3_c  \
# date_time
# 2023-06-22 14:16:06.761126                94.9               100.1
# 2023-06-22 14:16:12.104136                94.9               100.3
# 2023-06-22 14:16:17.457427                94.8               100.2
# 2023-06-22 14:16:25.906595                94.7                99.6
# 2023-06-22 14:16:33.827435                94.6                99.8
#
#                             secundary_pa16d6_c  secundary_p014d6_c  \
# date_time
# 2023-06-22 14:16:06.761126               102.2                95.8
# 2023-06-22 14:16:12.104136               102.2                95.8
# 2023-06-22 14:16:17.457427               102.2                95.8
# 2023-06-22 14:16:25.906595               102.2                95.8
# 2023-06-22 14:16:33.827435               102.2                95.8
#
#                             secundary_p015d6_c  secundary_multipressure_bar
# date_time
# 2023-06-22 14:16:06.761126               110.7                    14.624008
# 2023-06-22 14:16:12.104136               110.6                    14.967206
# 2023-06-22 14:16:17.457427               110.4                    15.272269
# 2023-06-22 14:16:25.906595               110.2                    14.776541
# 2023-06-22 14:16:33.827435               109.9                    15.234137

# %% [markdown]
# ## Verificación de la columna de tiempo este en el formato y tipo correcto

# %%
# Validar el tipo de la columna de tiempo sea el indice
print(processed_dataset.index)
# Out:
# DatetimeIndex(['2023-06-22 14:16:06.761126', '2023-06-22 14:16:12.104136',
#                '2023-06-22 14:16:17.457427', '2023-06-22 14:16:25.906595',
#                '2023-06-22 14:16:33.827435', '2023-06-22 14:16:38.907547',
#                '2023-06-22 14:16:43.990893', '2023-06-22 14:16:49.089285',
#                '2023-06-22 14:16:54.170175', '2023-06-22 14:16:59.267724',
#                ...
#                '2023-07-14 17:23:13.567633', '2023-07-14 17:23:18.638187',
#                '2023-07-14 17:23:23.707007', '2023-07-14 17:23:28.790062',
#                '2023-07-14 17:23:33.861161', '2023-07-14 17:23:38.935631',
#                '2023-07-14 17:23:44.017698', '2023-07-14 17:23:49.097439',
#                '2023-07-14 17:23:54.175396', '2023-07-14 17:23:59.251937'],
#               dtype='datetime64[ns]', name='date_time', length=375912, freq=None)

# %%
#Validamos si la columna de tiempo está en el formato correcto
print(f"Tipo de dato: {processed_dataset.index.dtype}")
# Out:
# Tipo de dato: datetime64[ns]

# %% [markdown]
# ## Verificación de valores nulos
#
# Las series de tiempo no pueden procesar valores nulos, por lo cual validamos que no existan

# %%
# Valorizamos si existen valores nulos en el dataset
null_values = processed_dataset.isnull().sum()
print("\nValores nulos por columna:")
print(null_values)
# Out:
# Valores nulos por columna:
# runautomode_bool               0
# actual_speed_m_min             0
# secundary_pumpspeed_rpm        0
# secundary_pa16d1_bar           0
# secundary_p014d1_bar           0
# secundary_p015d1_bar           0
# secundary_pa7b3_mm             0
# secundary_pa4b2_c              0
# secundary_pa4b5_c              0
# secundary_pu2b2_c              0
# secundary_p012b3_c             0
# secundary_p022b3_c             0
# secundary_pa16d6_c             0
# secundary_p014d6_c             0
# secundary_p015d6_c             0
# secundary_multipressure_bar    0
# dtype: int64

# %% [markdown]
# ## Procesamiento de variable categórica.
#
# Nuestro dataset presenta una variable categórica (runautomode_bool), la cual indica si la máquina esta funcionando o no, al ser un valor booleano, debemos procesarla como variable ordinal, ya que el valor true o 1 significa que la máquina esta funcionando y false o 0, que la máquina no esta funcionando, lo que hace que cuantitativamente 1 sea más que 0.

# %%
encoder = LabelEncoder()
processed_dataset['runautomode_bool'] = encoder.fit_transform(processed_dataset['runautomode_bool'])
processed_dataset.head()
# Out:
#                             runautomode_bool  actual_speed_m_min  \
# date_time
# 2023-06-22 14:16:06.761126                 1                 3.5
# 2023-06-22 14:16:12.104136                 1                 3.5
# 2023-06-22 14:16:17.457427                 1                 3.5
# 2023-06-22 14:16:25.906595                 1                 3.5
# 2023-06-22 14:16:33.827435                 1                 3.5
#
#                             secundary_pumpspeed_rpm  secundary_pa16d1_bar  \
# date_time
# 2023-06-22 14:16:06.761126                21.589945             33.216620
# 2023-06-22 14:16:12.104136                21.516739             33.197170
# 2023-06-22 14:16:17.457427                21.919836             33.122610
# 2023-06-22 14:16:25.906595                21.708180             33.070736
# 2023-06-22 14:16:33.827435                21.853577             33.161510
#
#                             secundary_p014d1_bar  secundary_p015d1_bar  \
# date_time
# 2023-06-22 14:16:06.761126              94.21156             57.346170
# 2023-06-22 14:16:12.104136              94.46119             57.368862
# 2023-06-22 14:16:17.457427              94.12079             57.312130
# 2023-06-22 14:16:25.906595              94.32503             57.266743
# 2023-06-22 14:16:33.827435              94.35907             57.391556
#
#                             secundary_pa7b3_mm  secundary_pa4b2_c  \
# date_time
# 2023-06-22 14:16:06.761126           34.467407               99.9
# 2023-06-22 14:16:12.104136           34.337220               99.9
# 2023-06-22 14:16:17.457427           34.402344               99.9
# 2023-06-22 14:16:25.906595           34.272156               99.9
# 2023-06-22 14:16:33.827435           34.239563               99.9
#
#                             secundary_pa4b5_c  secundary_pu2b2_c  \
# date_time
# 2023-06-22 14:16:06.761126              103.2               99.8
# 2023-06-22 14:16:12.104136              103.2               99.8
# 2023-06-22 14:16:17.457427              103.1               99.8
# 2023-06-22 14:16:25.906595              103.1               99.8
# 2023-06-22 14:16:33.827435              103.1               99.8
#
#                             secundary_p012b3_c  secundary_p022b3_c  \
# date_time
# 2023-06-22 14:16:06.761126                94.9               100.1
# 2023-06-22 14:16:12.104136                94.9               100.3
# 2023-06-22 14:16:17.457427                94.8               100.2
# 2023-06-22 14:16:25.906595                94.7                99.6
# 2023-06-22 14:16:33.827435                94.6                99.8
#
#                             secundary_pa16d6_c  secundary_p014d6_c  \
# date_time
# 2023-06-22 14:16:06.761126               102.2                95.8
# 2023-06-22 14:16:12.104136               102.2                95.8
# 2023-06-22 14:16:17.457427               102.2                95.8
# 2023-06-22 14:16:25.906595               102.2                95.8
# 2023-06-22 14:16:33.827435               102.2                95.8
#
#                             secundary_p015d6_c  secundary_multipressure_bar
# date_time
# 2023-06-22 14:16:06.761126               110.7                    14.624008
# 2023-06-22 14:16:12.104136               110.6                    14.967206
# 2023-06-22 14:16:17.457427               110.4                    15.272269
# 2023-06-22 14:16:25.906595               110.2                    14.776541
# 2023-06-22 14:16:33.827435               109.9                    15.234137

# %% [markdown]
# ## Selección de Features

# %% [markdown]
# ### Mutual Information

# %%
X = processed_dataset.drop(columns=["secundary_multipressure_bar"])
y = processed_dataset["secundary_multipressure_bar"]

mi = mutual_info_regression(X, y)
mi_series = pd.Series(mi, index=X.columns).sort_values(ascending=False)
print(mi_series)
# Out:
# secundary_p014d1_bar       1.115529
# secundary_p015d1_bar       1.015585
# secundary_pa7b3_mm         0.961033
# secundary_pa16d1_bar       0.924765
# secundary_pumpspeed_rpm    0.750249
# secundary_p014d6_c         0.721885
# secundary_pa4b2_c          0.708280
# secundary_p012b3_c         0.695483
# secundary_p015d6_c         0.692355
# secundary_pa4b5_c          0.683069
# secundary_pa16d6_c         0.680965
# secundary_pu2b2_c          0.677648
# secundary_p022b3_c         0.633559
# actual_speed_m_min         0.498456
# runautomode_bool           0.403984
# dtype: float64

# %% [markdown]
# ### Correlación Pearson

# %%
# Convertir columna booleana (si viene como 't'/'f')
#if X["runautomode_bool"].dtype == object:
#    X["runautomode_bool"] = X["runautomode_bool"].map({"t": 1, "f": 0})

# Calcular correlación de Pearson de cada feature respecto al target
pearson_corr = X.corrwith(y)

# Mostrar ordenado de mayor a menor correlación
print(pearson_corr.sort_values(ascending=False))
# Out:
# secundary_p022b3_c         0.511267
# secundary_p015d6_c         0.503195
# secundary_p012b3_c         0.498879
# secundary_p014d6_c         0.478289
# secundary_pa16d1_bar       0.469555
# secundary_pu2b2_c          0.460051
# secundary_pa16d6_c         0.426410
# secundary_pa4b2_c          0.391059
# secundary_pa4b5_c          0.365923
# secundary_p014d1_bar       0.151851
# secundary_p015d1_bar       0.122553
# runautomode_bool           0.022102
# actual_speed_m_min        -0.013593
# secundary_pa7b3_mm        -0.107916
# secundary_pumpspeed_rpm   -0.199604
# dtype: float64

# %% [markdown]
# - Si MI es alta y Pearson es baja → relación fuertemente no lineal
#
# - Si ambas son altas → relación lineal + no lineal
#
# - Si Pearson es alta y MI es baja → relación lineal simple (casi no pasa en tu dataset)
#
# | Feature                 | MI        | Pearson     | Interpretación del tipo de relación         |
# |-------------------------|-----------|-------------|----------------------------------------------|
# | secundary_p014d1_bar    | 1.257104  | 0.336581    | Alta importancia no lineal                  |
# | secundary_pa7b3_mm      | 1.224553  | -0.207830   | Fuerte relación no lineal, invertida        |
# | secundary_pa16d1_bar    | 1.129050  | 0.580413    | Relación mixta: lineal + no lineal          |
# | secundary_p015d1_bar    | 1.088624  | 0.297783    | No lineal moderada                           |
# | secundary_pa4b2_c       | 1.038111  | 0.415851    | Relación mixta                               |
# | secundary_p014d6_c      | 1.030959  | 0.581808    | Lineal moderada + componente no lineal       |
# | secundary_pa16d6_c      | 1.017278  | -0.100991   | No lineal débil, posible cambio de pendiente |
# | secundary_pa4b5_c       | 1.016413  | 0.421461    | Mixta                                        |
# | secundary_pu2b2_c       | 1.006020  | 0.387175    | Mixta                                        |
# | secundary_p012b3_c      | 0.995920  | 0.411354    | Mixta                                        |
# | secundary_p015d6_c      | 0.979866  | 0.537060    | Principalmente lineal                        |
# | secundary_p022b3_c      | 0.896165  | 0.609788    | Fuerte componente lineal                     |
# | secundary_pumpspeed_rpm | 0.741241  | -0.238969   | No lineal, efecto inverso                    |
# | actual_speed_m_min      | 0.526204  | 0.138413    | Débil lineal + algo de no linealidad         |
# | runautomode_bool        | 0.445946  | 0.174090    | Baja información lineal y no lineal          |

# %% [markdown]
# Tomando esta información se toma la decisión de descartar las variables "runautomode_bool" y "actual_speed_m_min". Estas variables aportan muy poca información sobre el target, tanto lineal como no lineal.

# %%
processed_dataset.drop(columns=['actual_speed_m_min','runautomode_bool'], inplace=True)
processed_dataset
# Out:
#                             secundary_pumpspeed_rpm  secundary_pa16d1_bar  \
# date_time
# 2023-06-22 14:16:06.761126                21.589945             33.216620
# 2023-06-22 14:16:12.104136                21.516739             33.197170
# 2023-06-22 14:16:17.457427                21.919836             33.122610
# 2023-06-22 14:16:25.906595                21.708180             33.070736
# 2023-06-22 14:16:33.827435                21.853577             33.161510
# ...                                             ...                   ...
# 2023-07-14 17:23:38.935631                 0.000000              2.295273
# 2023-07-14 17:23:44.017698                 0.000000              2.295273
# 2023-07-14 17:23:49.097439                 0.000000              2.295273
# 2023-07-14 17:23:54.175396                 0.000000              2.295273
# 2023-07-14 17:23:59.251937                 0.000000              2.295273
#
#                             secundary_p014d1_bar  secundary_p015d1_bar  \
# date_time
# 2023-06-22 14:16:06.761126             94.211560             57.346170
# 2023-06-22 14:16:12.104136             94.461190             57.368862
# 2023-06-22 14:16:17.457427             94.120790             57.312130
# 2023-06-22 14:16:25.906595             94.325030             57.266743
# 2023-06-22 14:16:33.827435             94.359070             57.391556
# ...                                          ...                   ...
# 2023-07-14 17:23:38.935631              2.382805             -0.885042
# 2023-07-14 17:23:44.017698              2.382805             -0.885042
# 2023-07-14 17:23:49.097439              2.382805             -0.885042
# 2023-07-14 17:23:54.175396              2.382805             -0.885042
# 2023-07-14 17:23:59.251937              2.382805             -0.885042
#
#                             secundary_pa7b3_mm  secundary_pa4b2_c  \
# date_time
# 2023-06-22 14:16:06.761126           34.467407               99.9
# 2023-06-22 14:16:12.104136           34.337220               99.9
# 2023-06-22 14:16:17.457427           34.402344               99.9
# 2023-06-22 14:16:25.906595           34.272156               99.9
# 2023-06-22 14:16:33.827435           34.239563               99.9
# ...                                        ...                ...
# 2023-07-14 17:23:38.935631          537.711400               93.9
# 2023-07-14 17:23:44.017698          537.711400               93.9
# 2023-07-14 17:23:49.097439          537.711400               93.9
# 2023-07-14 17:23:54.175396          537.711400               93.9
# 2023-07-14 17:23:59.251937          537.711400               93.9
#
#                             secundary_pa4b5_c  secundary_pu2b2_c  \
# date_time
# 2023-06-22 14:16:06.761126              103.2               99.8
# 2023-06-22 14:16:12.104136              103.2               99.8
# 2023-06-22 14:16:17.457427              103.1               99.8
# 2023-06-22 14:16:25.906595              103.1               99.8
# 2023-06-22 14:16:33.827435              103.1               99.8
# ...                                       ...                ...
# 2023-07-14 17:23:38.935631              101.9               75.1
# 2023-07-14 17:23:44.017698              101.9               75.1
# 2023-07-14 17:23:49.097439              101.9               75.1
# 2023-07-14 17:23:54.175396              101.9               75.1
# 2023-07-14 17:23:59.251937              101.9               75.1
#
#                             secundary_p012b3_c  secundary_p022b3_c  \
# date_time
# 2023-06-22 14:16:06.761126                94.9               100.1
# 2023-06-22 14:16:12.104136                94.9               100.3
# 2023-06-22 14:16:17.457427                94.8               100.2
# 2023-06-22 14:16:25.906595                94.7                99.6
# 2023-06-22 14:16:33.827435                94.6                99.8
# ...                                        ...                 ...
# 2023-07-14 17:23:38.935631                27.1                23.3
# 2023-07-14 17:23:44.017698                27.1                23.3
# 2023-07-14 17:23:49.097439                27.1                23.3
# 2023-07-14 17:23:54.175396                27.1                23.3
# 2023-07-14 17:23:59.251937                27.1                23.3
#
#                             secundary_pa16d6_c  secundary_p014d6_c  \
# date_time
# 2023-06-22 14:16:06.761126               102.2                95.8
# 2023-06-22 14:16:12.104136               102.2                95.8
# 2023-06-22 14:16:17.457427               102.2                95.8
# 2023-06-22 14:16:25.906595               102.2                95.8
# 2023-06-22 14:16:33.827435               102.2                95.8
# ...                                        ...                 ...
# 2023-07-14 17:23:38.935631                83.6                52.9
# 2023-07-14 17:23:44.017698                83.6                52.9
# 2023-07-14 17:23:49.097439                83.6                52.9
# 2023-07-14 17:23:54.175396                83.6                52.9
# 2023-07-14 17:23:59.251937                83.6                52.9
#
#                             secundary_p015d6_c  secundary_multipressure_bar
# date_time
# 2023-06-22 14:16:06.761126               110.7                    14.624008
# 2023-06-22 14:16:12.104136               110.6                    14.967206
# 2023-06-22 14:16:17.457427               110.4                    15.272269
# 2023-06-22 14:16:25.906595               110.2                    14.776541
# 2023-06-22 14:16:33.827435               109.9                    15.234137
# ...                                        ...                          ...
# 2023-07-14 17:23:38.935631                27.0                     0.838926
# 2023-07-14 17:23:44.017698                27.0                     0.838926
# 2023-07-14 17:23:49.097439                27.0                     0.838926
# 2023-07-14 17:23:54.175396                27.0                     0.838926
# 2023-07-14 17:23:59.251937                27.0                     0.838926
#
# [375912 rows x 14 columns]

# %%
processed_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 375912 entries, 2023-06-22 14:16:06.761126 to 2023-07-14 17:23:59.251937
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   secundary_pumpspeed_rpm      375912 non-null  float64
#  1   secundary_pa16d1_bar         375912 non-null  float64
#  2   secundary_p014d1_bar         375912 non-null  float64
#  3   secundary_p015d1_bar         375912 non-null  float64
#  4   secundary_pa7b3_mm           375912 non-null  float64
#  5   secundary_pa4b2_c            375912 non-null  float64
#  6   secundary_pa4b5_c            375912 non-null  float64
#  7   secundary_pu2b2_c            375912 non-null  float64
#  8   secundary_p012b3_c           375912 non-null  float64
#  9   secundary_p022b3_c           375912 non-null  float64
#  10  secundary_pa16d6_c           375912 non-null  float64
#  11  secundary_p014d6_c           375912 non-null  float64
#  12  secundary_p015d6_c           375912 non-null  float64
#  13  secundary_multipressure_bar  375912 non-null  float64
# dtypes: float64(14)
# memory usage: 43.0 MB

# %% [markdown]
# ## Filtrado e imputación de datos

# %% [markdown]
# Como se ve en la descripción de los datos en la tabla de abajo, existen valores de sensores que son negativos, sin embargo con el criterio del experto del área, no pueden existir presiones ni temperaturas negativas ya que es físicamente imposible, pueden ser errores en sensores, malas calibraciones, etc. Por lo tanto estos datos deben de tratarse.

# %%
processed_dataset.describe()
# Out:
#        secundary_pumpspeed_rpm  secundary_pa16d1_bar  secundary_p014d1_bar  \
# count            375912.000000         375912.000000         375912.000000
# mean                 34.593661             27.679514             92.020630
# std                  26.956397              9.830933             55.664310
# min                   0.000000              1.455618              1.066589
# 25%                   0.982634             29.251766             29.864487
# 50%                  41.446367             30.162743            122.748490
# 75%                  54.599004             32.723854            140.835110
# max                 100.000000             38.902935            295.104700
#
#        secundary_p015d1_bar  secundary_pa7b3_mm  secundary_pa4b2_c  \
# count         375912.000000       375912.000000      375912.000000
# mean              56.156945          287.969290          95.423379
# std               40.397132          168.549777          14.446986
# min               -1.157362            6.509399          29.400000
# 25%                5.537184          148.577700          99.800000
# 50%               78.326195          286.642730          99.900000
# 75%               92.112430          431.347350         100.100000
# max              277.052120          730.227840         101.300000
#
#        secundary_pa4b5_c  secundary_pu2b2_c  secundary_p012b3_c  \
# count      375912.000000      375912.000000       375912.000000
# mean           99.041047          94.336670           85.152146
# std            15.151891          15.133108           21.937484
# min            29.900000          29.400000           27.100000
# 25%           103.000000          99.800000           86.100000
# 50%           103.500000          99.900000           94.300000
# 75%           103.800000         100.100000           97.200000
# max           105.600000         102.200000          104.700000
#
#        secundary_p022b3_c  secundary_pa16d6_c  secundary_p014d6_c  \
# count       375912.000000       375912.000000       375912.000000
# mean            89.914064           96.440773           85.150868
# std             24.818705           15.440336           15.012315
# min             23.200000         -163.900000           29.000000
# 25%             99.600000          101.200000           89.200000
# 50%             99.900000          101.600000           90.400000
# 75%            100.200000          102.000000           91.800000
# max            102.300000          869.900000           97.200000
#
#        secundary_p015d6_c  secundary_multipressure_bar
# count       375912.000000                375912.000000
# mean            96.224506                    15.197297
# std             26.504428                    10.967300
# min             27.000000                    -1.544387
# 25%             98.100000                    13.861348
# 50%            105.800000                    14.967206
# 75%            111.100000                    15.405735
# max            127.700000                    80.174650

# %% [markdown]
# Como estas filas perteneces a una secuencia de datos, eliminarlas podría significar una perdida de información o podría entrenarse el modelo con eventos con gaps incoherentes, deformar los lags (ya que no sería espacios iguales)

# %%
processed_dataset.count()
# Out:
# secundary_pumpspeed_rpm        375912
# secundary_pa16d1_bar           375912
# secundary_p014d1_bar           375912
# secundary_p015d1_bar           375912
# secundary_pa7b3_mm             375912
# secundary_pa4b2_c              375912
# secundary_pa4b5_c              375912
# secundary_pu2b2_c              375912
# secundary_p012b3_c             375912
# secundary_p022b3_c             375912
# secundary_pa16d6_c             375912
# secundary_p014d6_c             375912
# secundary_p015d6_c             375912
# secundary_multipressure_bar    375912
# dtype: int64

# %%
cols = ["secundary_p014d1_bar", "secundary_pa16d1_bar",
        "secundary_multipressure_bar", "secundary_pa7b3_mm",
       "secundary_p015d1_bar","secundary_pa4b5_c",
       "secundary_p012b3_c","secundary_pa16d6_c",
       "secundary_p015d6_c"]

(processed_dataset["secundary_p014d1_bar"] < 0).sum()

for col in cols:
    neg_values = (processed_dataset[col] < 0).sum()
    print(f"En la columna {col}: {neg_values} imputan")
    porcentage = neg_values/processed_dataset[col].count()*100
    print(f"El porcetaje de datos perdido es de: {porcentage}")
    print("\n")
# Out:
# En la columna secundary_p014d1_bar: 0 imputan
# El porcetaje de datos perdido es de: 0.0
#
#
# En la columna secundary_pa16d1_bar: 0 imputan
# El porcetaje de datos perdido es de: 0.0
#
#
# En la columna secundary_multipressure_bar: 18077 imputan
# El porcetaje de datos perdido es de: 4.808838238736725
#
#
# En la columna secundary_pa7b3_mm: 0 imputan
# El porcetaje de datos perdido es de: 0.0
#
#
# En la columna secundary_p015d1_bar: 60321 imputan
# El porcetaje de datos perdido es de: 16.046574730256015
#
#
# En la columna secundary_pa4b5_c: 0 imputan
# El porcetaje de datos perdido es de: 0.0
#
#
# En la columna secundary_p012b3_c: 0 imputan
# El porcetaje de datos perdido es de: 0.0
#
#
# En la columna secundary_pa16d6_c: 2 imputan
# El porcetaje de datos perdido es de: 0.0005320394134797506
#
#
# En la columna secundary_p015d6_c: 0 imputan
# El porcetaje de datos perdido es de: 0.0

# %% [markdown]
# Todas las columnas, exceptuando las columns secundary_multipressure_bar y columna secundary_p015d1_bar, representan un bajo porcentaje de los datos por lo que se realizará la imputación sin mayor análisis:

# %%
cols = ["secundary_p014d1_bar", "secundary_pa16d1_bar",
       "secundary_pa7b3_mm",
       "secundary_pa4b5_c",
       "secundary_p012b3_c","secundary_pa16d6_c",
       "secundary_p015d6_c"]

for col in cols:
    processed_dataset[col] = processed_dataset[col].mask(processed_dataset[col] < 0, np.nan)
    processed_dataset[col] = processed_dataset[col].interpolate(method="time")

processed_dataset.describe()
# Out:
#        secundary_pumpspeed_rpm  secundary_pa16d1_bar  secundary_p014d1_bar  \
# count            375912.000000         375912.000000         375912.000000
# mean                 34.593661             27.679514             92.020630
# std                  26.956397              9.830933             55.664310
# min                   0.000000              1.455618              1.066589
# 25%                   0.982634             29.251766             29.864487
# 50%                  41.446367             30.162743            122.748490
# 75%                  54.599004             32.723854            140.835110
# max                 100.000000             38.902935            295.104700
#
#        secundary_p015d1_bar  secundary_pa7b3_mm  secundary_pa4b2_c  \
# count         375912.000000       375912.000000      375912.000000
# mean              56.156945          287.969290          95.423379
# std               40.397132          168.549777          14.446986
# min               -1.157362            6.509399          29.400000
# 25%                5.537184          148.577700          99.800000
# 50%               78.326195          286.642730          99.900000
# 75%               92.112430          431.347350         100.100000
# max              277.052120          730.227840         101.300000
#
#        secundary_pa4b5_c  secundary_pu2b2_c  secundary_p012b3_c  \
# count      375912.000000      375912.000000       375912.000000
# mean           99.041047          94.336670           85.152146
# std            15.151891          15.133108           21.937484
# min            29.900000          29.400000           27.100000
# 25%           103.000000          99.800000           86.100000
# 50%           103.500000          99.900000           94.300000
# 75%           103.800000         100.100000           97.200000
# max           105.600000         102.200000          104.700000
#
#        secundary_p022b3_c  secundary_pa16d6_c  secundary_p014d6_c  \
# count       375912.000000       375912.000000       375912.000000
# mean            89.914064           96.443704           85.150868
# std             24.818705           15.457642           15.012315
# min             23.200000           28.900000           29.000000
# 25%             99.600000          101.200000           89.200000
# 50%             99.900000          101.600000           90.400000
# 75%            100.200000          102.000000           91.800000
# max            102.300000          869.900000           97.200000
#
#        secundary_p015d6_c  secundary_multipressure_bar
# count       375912.000000                375912.000000
# mean            96.224506                    15.197297
# std             26.504428                    10.967300
# min             27.000000                    -1.544387
# 25%             98.100000                    13.861348
# 50%            105.800000                    14.967206
# 75%            111.100000                    15.405735
# max            127.700000                    80.174650

# %% [markdown]
# Sin embargo las columns secundary_multipressure_bar y columna secundary_p015d1_bar sí se van a ver a detalles los valores negativos

# %%
processed_dataset.secundary_multipressure_bar[processed_dataset.secundary_multipressure_bar<0].plot()
# Out:
# <Axes: xlabel='date_time'>

# %% [markdown]
# La gráfica evidencia como los valores menores a 0 con varios pero la mayoría están muy cerca de cero, se sospecha que el problema es calibraciones del equipo.

# %%
processed_dataset.secundary_multipressure_bar[processed_dataset.secundary_multipressure_bar<0].describe()
# Out:
# count    18077.000000
# mean        -0.842602
# std          0.152126
# min         -1.544387
# 25%         -0.896126
# 50%         -0.819860
# 75%         -0.781727
# max         -0.019067
# Name: secundary_multipressure_bar, dtype: float64

# %%
IQR = processed_dataset.secundary_multipressure_bar[processed_dataset.secundary_multipressure_bar<0].quantile(0.75) - processed_dataset.secundary_multipressure_bar[processed_dataset.secundary_multipressure_bar<0].quantile(0.25)

LL = processed_dataset.secundary_multipressure_bar[processed_dataset.secundary_multipressure_bar<0].quantile(0.25) -1.5*IQR
LL
# Out:
# np.float64(-1.06772426)

# %% [markdown]
# Se toma la decisión de iterpolar solo los datos que se salen del límite de outliers en los datos menores a cero.

# %%
processed_dataset.secundary_multipressure_bar = processed_dataset.secundary_multipressure_bar.mask(processed_dataset.secundary_multipressure_bar < LL, np.nan)
processed_dataset.secundary_multipressure_bar = processed_dataset.secundary_multipressure_bar.interpolate(method="time")

# %%
processed_dataset.secundary_p015d1_bar[processed_dataset.secundary_p015d1_bar<0].plot()
# Out:
# <Axes: xlabel='date_time'>

# %% [markdown]
# La gráfica evidencia como los valores menores a 0 con varios pero la mayoría están muy cerca de cero, se sospecha que el problema es calibraciones del equipo.

# %%
processed_dataset.secundary_p015d1_bar[processed_dataset.secundary_p015d1_bar<0].describe()
# Out:
# count    60321.000000
# mean        -0.704818
# std          0.351262
# min         -1.157362
# 25%         -0.919082
# 50%         -0.885042
# 75%         -0.510601
# max         -0.011347
# Name: secundary_p015d1_bar, dtype: float64

# %%
IQR = processed_dataset.secundary_p015d1_bar[processed_dataset.secundary_p015d1_bar<0].quantile(0.75) - processed_dataset.secundary_p015d1_bar[processed_dataset.secundary_p015d1_bar<0].quantile(0.25)

LL = processed_dataset.secundary_p015d1_bar[processed_dataset.secundary_p015d1_bar<0].quantile(0.25) -1.5*IQR
LL
# Out:
# np.float64(-1.531803115)

# %% [markdown]
# Se toma la decisión de iterpolar solo los datos que se salen del límite de outliers en los datos menores a cero.

# %%
processed_dataset.secundary_p015d1_bar = processed_dataset.secundary_p015d1_bar.mask(processed_dataset.secundary_p015d1_bar < LL, np.nan)
processed_dataset.secundary_p015d1_bar = processed_dataset.secundary_p015d1_bar.interpolate(method="time")

# %% [markdown]
# #### Descripción Final de los datos

# %%
processed_dataset.describe()
# Out:
#        secundary_pumpspeed_rpm  secundary_pa16d1_bar  secundary_p014d1_bar  \
# count            375912.000000         375912.000000         375912.000000
# mean                 34.593661             27.679514             92.020630
# std                  26.956397              9.830933             55.664310
# min                   0.000000              1.455618              1.066589
# 25%                   0.982634             29.251766             29.864487
# 50%                  41.446367             30.162743            122.748490
# 75%                  54.599004             32.723854            140.835110
# max                 100.000000             38.902935            295.104700
#
#        secundary_p015d1_bar  secundary_pa7b3_mm  secundary_pa4b2_c  \
# count         375912.000000       375912.000000      375912.000000
# mean              56.156945          287.969290          95.423379
# std               40.397132          168.549777          14.446986
# min               -1.157362            6.509399          29.400000
# 25%                5.537184          148.577700          99.800000
# 50%               78.326195          286.642730          99.900000
# 75%               92.112430          431.347350         100.100000
# max              277.052120          730.227840         101.300000
#
#        secundary_pa4b5_c  secundary_pu2b2_c  secundary_p012b3_c  \
# count      375912.000000      375912.000000       375912.000000
# mean           99.041047          94.336670           85.152146
# std            15.151891          15.133108           21.937484
# min            29.900000          29.400000           27.100000
# 25%           103.000000          99.800000           86.100000
# 50%           103.500000          99.900000           94.300000
# 75%           103.800000         100.100000           97.200000
# max           105.600000         102.200000          104.700000
#
#        secundary_p022b3_c  secundary_pa16d6_c  secundary_p014d6_c  \
# count       375912.000000       375912.000000       375912.000000
# mean            89.914064           96.443704           85.150868
# std             24.818705           15.457642           15.012315
# min             23.200000           28.900000           29.000000
# 25%             99.600000          101.200000           89.200000
# 50%             99.900000          101.600000           90.400000
# 75%            100.200000          102.000000           91.800000
# max            102.300000          869.900000           97.200000
#
#        secundary_p015d6_c  secundary_multipressure_bar
# count       375912.000000                375912.000000
# mean            96.224506                    15.198035
# std             26.504428                    10.966220
# min             27.000000                    -1.067724
# 25%             98.100000                    13.861348
# 50%            105.800000                    14.967206
# 75%            111.100000                    15.405735
# max            127.700000                    80.174650

# %% [markdown]
# ## Lag Features
# Vamos a generar un lag de 5. Vamos a usar lag features para darle al modelo una memoria del pasado. Básicamente, creamos nuevas columnas que contienen los valores de la variable de momentos anteriores. Esto es muy importante porque el modelo no entiende el tiempo por sí solo. Al darle estas pistas del pasado, le ayudamos a reconocer patrones y a usar la información anterior para predecir lo que va a suceder.

# %%
processed_dataset = processed_dataset.copy()

target_col = "secundary_multipressure_bar"

# Grupos de features según MI
group_A = [
    "secundary_p014d1_bar",
    "secundary_pa7b3_mm",
    "secundary_pa16d1_bar",
    "secundary_p015d1_bar",
    "secundary_pa4b2_c",
    "secundary_p014d6_c"
]

group_B = [
    "secundary_pa16d6_c",
    "secundary_pa4b5_c",
    "secundary_p012b3_c",
    "secundary_pu2b2_c",
    "secundary_p015d6_c",
    "secundary_p022b3_c"
]

group_C = [
    "secundary_pumpspeed_rpm"
]

# Número de lags por grupo
lags_A = 36
lags_B = 36
lags_C = 36

# Función para generar lags de una lista de columnas
def create_lags(df, cols, n_lags):
    for col in cols:
        for lag in range(1, n_lags + 1):
            df[f"{col}_lag_{lag}"] = df[col].shift(lag)

# Crear lags por grupo directamente en processed_dataset
create_lags(processed_dataset, group_A, lags_A)
create_lags(processed_dataset, group_B, lags_B)
create_lags(processed_dataset, group_C, lags_C)

# Crear el target futuro (+12 pasos = ~1 minuto hacia adelante)
processed_dataset["target_plus_12"] = processed_dataset[target_col].shift(-12)

# Eliminar filas con NaN (primeros 36 y últimos 12)
processed_dataset = processed_dataset.dropna()

processed_dataset.shape, processed_dataset.head()
# Out:
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# ...
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_lag_{lag}"] = df[col].shift(lag)
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/1189234227.py:45: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   processed_dataset["target_plus_12"] = processed_dataset[target_col].shift(-12)
# ((375864, 483),
#                              secundary_pumpspeed_rpm  secundary_pa16d1_bar  \
#  date_time
#  2023-06-22 14:19:18.792007                41.999100             31.806393
#  2023-06-22 14:19:23.870469                41.204315             31.783699
#  2023-06-22 14:19:28.946102                40.889020             31.816118
#  2023-06-22 14:19:34.030097                39.407448             31.761005
#  2023-06-22 14:19:39.106186                39.635914             31.842052
#
#                              secundary_p014d1_bar  secundary_p015d1_bar  \
#  date_time
#  2023-06-22 14:19:18.792007            127.400630              85.06613
#  2023-06-22 14:19:23.870469            127.888535              85.73559
#  2023-06-22 14:19:28.946102            126.595020              84.80516
#  2023-06-22 14:19:34.030097            125.653240              84.35129
#  2023-06-22 14:19:39.106186            126.719826              84.97536
#
#                              secundary_pa7b3_mm  secundary_pa4b2_c  \
#  date_time
#  2023-06-22 14:19:18.792007           30.398987               99.9
#  2023-06-22 14:19:23.870469           30.301392              100.0
#  2023-06-22 14:19:28.946102           29.943360              100.0
#  2023-06-22 14:19:34.030097           29.748047              100.0
#  2023-06-22 14:19:39.106186           29.617859              100.0
#
#                              secundary_pa4b5_c  secundary_pu2b2_c  \
#  date_time
#  2023-06-22 14:19:18.792007              103.3               99.9
#  2023-06-22 14:19:23.870469              103.3              100.0
#  2023-06-22 14:19:28.946102              103.3              100.0
#  2023-06-22 14:19:34.030097              103.3              100.0
#  2023-06-22 14:19:39.106186              103.3               99.9
#
#                              secundary_p012b3_c  secundary_p022b3_c  ...  \
#  date_time                                                           ...
#  2023-06-22 14:19:18.792007                93.7               100.2  ...
#  2023-06-22 14:19:23.870469                93.7                99.9  ...
#  2023-06-22 14:19:28.946102                93.8                99.8  ...
#  2023-06-22 14:19:34.030097                93.8                99.9  ...
#  2023-06-22 14:19:39.106186                93.9               100.2  ...
#
#                              secundary_pumpspeed_rpm_lag_28  \
#  date_time
#  2023-06-22 14:19:18.792007                       22.028550
#  2023-06-22 14:19:23.870469                       21.660437
#  2023-06-22 14:19:28.946102                       21.493917
#  2023-06-22 14:19:34.030097                       21.818357
#  2023-06-22 14:19:39.106186                       21.749691
#
#                              secundary_pumpspeed_rpm_lag_29  \
#  date_time
#  2023-06-22 14:19:18.792007                       21.709640
#  2023-06-22 14:19:23.870469                       22.028550
#  2023-06-22 14:19:28.946102                       21.660437
#  2023-06-22 14:19:34.030097                       21.493917
#  2023-06-22 14:19:39.106186                       21.818357
#
#                              secundary_pumpspeed_rpm_lag_30  \
#  date_time
#  2023-06-22 14:19:18.792007                       21.635485
#  2023-06-22 14:19:23.870469                       21.709640
#  2023-06-22 14:19:28.946102                       22.028550
#  2023-06-22 14:19:34.030097                       21.660437
#  2023-06-22 14:19:39.106186                       21.493917
#
#                              secundary_pumpspeed_rpm_lag_31  \
#  date_time
#  2023-06-22 14:19:18.792007                       21.604116
#  2023-06-22 14:19:23.870469                       21.635485
#  2023-06-22 14:19:28.946102                       21.709640
#  2023-06-22 14:19:34.030097                       22.028550
#  2023-06-22 14:19:39.106186                       21.660437
#
#                              secundary_pumpspeed_rpm_lag_32  \
#  date_time
#  2023-06-22 14:19:18.792007                       21.853577
#  2023-06-22 14:19:23.870469                       21.604116
#  2023-06-22 14:19:28.946102                       21.635485
#  2023-06-22 14:19:34.030097                       21.709640
#  2023-06-22 14:19:39.106186                       22.028550
#
#                              secundary_pumpspeed_rpm_lag_33  \
#  date_time
#  2023-06-22 14:19:18.792007                       21.708180
#  2023-06-22 14:19:23.870469                       21.853577
#  2023-06-22 14:19:28.946102                       21.604116
#  2023-06-22 14:19:34.030097                       21.635485
#  2023-06-22 14:19:39.106186                       21.709640
#
#                              secundary_pumpspeed_rpm_lag_34  \
#  date_time
#  2023-06-22 14:19:18.792007                       21.919836
#  2023-06-22 14:19:23.870469                       21.708180
#  2023-06-22 14:19:28.946102                       21.853577
#  2023-06-22 14:19:34.030097                       21.604116
#  2023-06-22 14:19:39.106186                       21.635485
#
#                              secundary_pumpspeed_rpm_lag_35  \
#  date_time
#  2023-06-22 14:19:18.792007                       21.516739
#  2023-06-22 14:19:23.870469                       21.919836
#  2023-06-22 14:19:28.946102                       21.708180
#  2023-06-22 14:19:34.030097                       21.853577
#  2023-06-22 14:19:39.106186                       21.604116
#
#                              secundary_pumpspeed_rpm_lag_36  target_plus_12
#  date_time
#  2023-06-22 14:19:18.792007                       21.589945       15.653600
#  2023-06-22 14:19:23.870469                       21.516739       14.986272
#  2023-06-22 14:19:28.946102                       21.919836       14.890940
#  2023-06-22 14:19:34.030097                       21.708180       15.329469
#  2023-06-22 14:19:39.106186                       21.853577       15.443869
#
#  [5 rows x 483 columns])

# %% [markdown]
# Los lags usan shift positivo porque miran al pasado, mientras que el target futuro usa shift negativo porque trae el futuro al presente para entrenar el modelo.

# %%
print(f"Features generadas después de lags por grupo: {processed_dataset.shape[1]}")
# Out:
# Features generadas después de lags por grupo: 483

# %% [markdown]
# ## Rolling Means
# Lo utilizamos para suavizar las fluctuaciones a corto plazo y resaltar la tendencia subyacente en los datos. Funciona calculando el promedio de un conjunto de puntos dentro de una ventana de tamaño fijo que se desliza a lo largo de toda la serie. Al promediar estos puntos, se reduce el "ruido" o las variaciones aleatorias, lo que permite una visualización más clara de la dirección y los patrones a largo plazo, facilitando así el análisis de la tendencia general.

# %%
window_size = 12

processed_dataset['target_MEAN'] = processed_dataset['secundary_multipressure_bar'].shift(1).rolling(window=window_size).mean()
processed_dataset['target_STD'] = processed_dataset['secundary_multipressure_bar'].shift(1).rolling(window=window_size).std()
processed_dataset['target_MIN'] = processed_dataset['secundary_multipressure_bar'].shift(1).rolling(window=window_size).min()
processed_dataset['target_MAX'] = processed_dataset['secundary_multipressure_bar'].shift(1).rolling(window=window_size).max()
processed_dataset = processed_dataset.dropna()

print(f"Features finales: {processed_dataset.shape[1]}")
processed_dataset.head(10)
# Out:
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/2801060484.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   processed_dataset['target_MEAN'] = processed_dataset['secundary_multipressure_bar'].shift(1).rolling(window=window_size).mean()
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/2801060484.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   processed_dataset['target_STD'] = processed_dataset['secundary_multipressure_bar'].shift(1).rolling(window=window_size).std()
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/2801060484.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   processed_dataset['target_MIN'] = processed_dataset['secundary_multipressure_bar'].shift(1).rolling(window=window_size).min()
# /var/folders/r6/gz2385611tq1vsnbq6sl32bw0000gn/T/ipykernel_1587/2801060484.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   processed_dataset['target_MAX'] = processed_dataset['secundary_multipressure_bar'].shift(1).rolling(window=window_size).max()
# Features finales: 487
#                             secundary_pumpspeed_rpm  secundary_pa16d1_bar  \
# date_time
# 2023-06-22 14:20:19.801173                41.080334             31.738312
# 2023-06-22 14:20:24.866509                40.679600             31.702650
# 2023-06-22 14:20:29.950502                39.432655             31.660505
# 2023-06-22 14:20:35.029907                40.503200             31.534071
# 2023-06-22 14:20:40.101851                41.316950             31.751280
# 2023-06-22 14:20:45.173293                40.128124             31.689682
# 2023-06-22 14:20:50.241122                40.182632             31.624846
# 2023-06-22 14:20:55.316144                40.598020             31.553522
# 2023-06-22 14:21:00.386923                40.630264             31.585941
# 2023-06-22 14:21:05.472136                40.079910             31.572973
#
#                             secundary_p014d1_bar  secundary_p015d1_bar  \
# date_time
# 2023-06-22 14:20:19.801173            124.348366             83.205280
# 2023-06-22 14:20:24.866509            123.735650             82.842180
# 2023-06-22 14:20:29.950502            123.894500             83.057770
# 2023-06-22 14:20:35.029907            123.792380             83.443560
# 2023-06-22 14:20:40.101851            123.849110             82.819490
# 2023-06-22 14:20:45.173293            123.599490             82.785446
# 2023-06-22 14:20:50.241122            123.520060             82.796790
# 2023-06-22 14:20:55.316144            123.259090             82.864876
# 2023-06-22 14:21:00.386923            122.703100             82.195420
# 2023-06-22 14:21:05.472136            122.635020             82.388310
#
#                             secundary_pa7b3_mm  secundary_pa4b2_c  \
# date_time
# 2023-06-22 14:20:19.801173           28.543823               99.9
# 2023-06-22 14:20:24.866509           28.478760               99.9
# 2023-06-22 14:20:29.950502           28.446167               99.9
# 2023-06-22 14:20:35.029907           28.283447              100.0
# 2023-06-22 14:20:40.101851           28.055603              100.0
# 2023-06-22 14:20:45.173293           27.827820              100.0
# 2023-06-22 14:20:50.241122           27.599976               99.9
# 2023-06-22 14:20:55.316144           27.274475               99.9
# 2023-06-22 14:21:00.386923           27.274475               99.9
# 2023-06-22 14:21:05.472136           26.949036               99.9
#
#                             secundary_pa4b5_c  secundary_pu2b2_c  \
# date_time
# 2023-06-22 14:20:19.801173              103.2               99.9
# 2023-06-22 14:20:24.866509              103.2               99.8
# 2023-06-22 14:20:29.950502              103.2               99.9
# 2023-06-22 14:20:35.029907              103.3               99.9
# 2023-06-22 14:20:40.101851              103.3               99.9
# 2023-06-22 14:20:45.173293              103.3               99.9
# 2023-06-22 14:20:50.241122              103.2               99.9
# 2023-06-22 14:20:55.316144              103.2               99.9
# 2023-06-22 14:21:00.386923              103.3               99.8
# 2023-06-22 14:21:05.472136              103.3               99.9
#
#                             secundary_p012b3_c  secundary_p022b3_c  ...  \
# date_time                                                           ...
# 2023-06-22 14:20:19.801173                94.5               100.1  ...
# 2023-06-22 14:20:24.866509                94.6                99.8  ...
# 2023-06-22 14:20:29.950502                94.7                99.7  ...
# 2023-06-22 14:20:35.029907                94.8                99.9  ...
# 2023-06-22 14:20:40.101851                94.9               100.2  ...
# 2023-06-22 14:20:45.173293                95.0               100.2  ...
# 2023-06-22 14:20:50.241122                95.1               100.1  ...
# 2023-06-22 14:20:55.316144                95.2                99.8  ...
# 2023-06-22 14:21:00.386923                95.3                99.6  ...
# 2023-06-22 14:21:05.472136                95.4                99.9  ...
#
#                             secundary_pumpspeed_rpm_lag_32  \
# date_time
# 2023-06-22 14:20:19.801173                       28.471409
# 2023-06-22 14:20:24.866509                       30.506277
# 2023-06-22 14:20:29.950502                       32.320232
# 2023-06-22 14:20:35.029907                       35.783356
# 2023-06-22 14:20:40.101851                       31.778254
# 2023-06-22 14:20:45.173293                       30.558435
# 2023-06-22 14:20:50.241122                       31.213974
# 2023-06-22 14:20:55.316144                       30.807728
# 2023-06-22 14:21:00.386923                       30.262762
# 2023-06-22 14:21:05.472136                       30.702250
#
#                             secundary_pumpspeed_rpm_lag_33  \
# date_time
# 2023-06-22 14:20:19.801173                       25.683084
# 2023-06-22 14:20:24.866509                       28.471409
# 2023-06-22 14:20:29.950502                       30.506277
# 2023-06-22 14:20:35.029907                       32.320232
# 2023-06-22 14:20:40.101851                       35.783356
# 2023-06-22 14:20:45.173293                       31.778254
# 2023-06-22 14:20:50.241122                       30.558435
# 2023-06-22 14:20:55.316144                       31.213974
# 2023-06-22 14:21:00.386923                       30.807728
# 2023-06-22 14:21:05.472136                       30.262762
#
#                             secundary_pumpspeed_rpm_lag_34  \
# date_time
# 2023-06-22 14:20:19.801173                       21.831861
# 2023-06-22 14:20:24.866509                       25.683084
# 2023-06-22 14:20:29.950502                       28.471409
# 2023-06-22 14:20:35.029907                       30.506277
# 2023-06-22 14:20:40.101851                       32.320232
# 2023-06-22 14:20:45.173293                       35.783356
# 2023-06-22 14:20:50.241122                       31.778254
# 2023-06-22 14:20:55.316144                       30.558435
# 2023-06-22 14:21:00.386923                       31.213974
# 2023-06-22 14:21:05.472136                       30.807728
#
#                             secundary_pumpspeed_rpm_lag_35  \
# date_time
# 2023-06-22 14:20:19.801173                       21.756290
# 2023-06-22 14:20:24.866509                       21.831861
# 2023-06-22 14:20:29.950502                       25.683084
# 2023-06-22 14:20:35.029907                       28.471409
# 2023-06-22 14:20:40.101851                       30.506277
# 2023-06-22 14:20:45.173293                       32.320232
# 2023-06-22 14:20:50.241122                       35.783356
# 2023-06-22 14:20:55.316144                       31.778254
# 2023-06-22 14:21:00.386923                       30.558435
# 2023-06-22 14:21:05.472136                       31.213974
#
#                             secundary_pumpspeed_rpm_lag_36  target_plus_12  \
# date_time
# 2023-06-22 14:20:19.801173                       21.749691       15.005339
# 2023-06-22 14:20:24.866509                       21.756290       15.215070
# 2023-06-22 14:20:29.950502                       21.831861       15.234137
# 2023-06-22 14:20:35.029907                       25.683084       15.100671
# 2023-06-22 14:20:40.101851                       28.471409       14.948139
# 2023-06-22 14:20:45.173293                       30.506277       15.443869
# 2023-06-22 14:20:50.241122                       32.320232       14.910006
# 2023-06-22 14:20:55.316144                       35.783356       14.910006
# 2023-06-22 14:21:00.386923                       31.778254       15.253203
# 2023-06-22 14:21:05.472136                       30.558435       14.414277
#
#                             target_MEAN  target_STD  target_MIN  target_MAX
# date_time
# 2023-06-22 14:20:19.801173    15.682200    0.482931   15.062538   16.473460
# 2023-06-22 14:20:24.866509    15.731455    0.442428   15.062538   16.473460
# 2023-06-22 14:20:29.950502    15.698088    0.483945   14.986272   16.473460
# 2023-06-22 14:20:35.029907    15.601167    0.521215   14.890940   16.473460
# 2023-06-22 14:20:40.101851    15.550323    0.514921   14.890940   16.473460
# 2023-06-22 14:20:45.173293    15.464524    0.425056   14.890940   16.320927
# 2023-06-22 14:20:50.241122    15.383491    0.328720   14.890940   15.920531
# 2023-06-22 14:20:55.316144    15.366013    0.343722   14.890940   15.920531
# 2023-06-22 14:21:00.386923    15.270681    0.334463   14.776541   15.844265
# 2023-06-22 14:21:05.472136    15.223015    0.281919   14.776541   15.653600
#
# [10 rows x 487 columns]

# %% [markdown]
# ## Creación de los conjuntos X & Y

# %%
#Conjunto Y
Y = processed_dataset["target_plus_12"]

#Conjunto X
X = processed_dataset.drop(columns=["target_plus_12"])

print("Dimensiones de los conjuntos:")
print(f"X: {X.shape}")
print(f"Y: {Y.shape}")
# Out:
# Dimensiones de los conjuntos:
# X: (375852, 486)
# Y: (375852,)

# %%
print("\n--- Variable Objetivo 'Y' (primeras 5 filas) ---")
Y.head()
# Out:
# --- Variable Objetivo 'Y' (primeras 5 filas) ---
# date_time
# 2023-06-22 14:20:19.801173    15.005339
# 2023-06-22 14:20:24.866509    15.215070
# 2023-06-22 14:20:29.950502    15.234137
# 2023-06-22 14:20:35.029907    15.100671
# 2023-06-22 14:20:40.101851    14.948139
# Name: target_plus_12, dtype: float64

# %%
print("\n--- Matriz de Características 'X' (primeras 5 filas) ---")
X.head()
# Out:
# --- Matriz de Características 'X' (primeras 5 filas) ---
#                             secundary_pumpspeed_rpm  secundary_pa16d1_bar  \
# date_time
# 2023-06-22 14:20:19.801173                41.080334             31.738312
# 2023-06-22 14:20:24.866509                40.679600             31.702650
# 2023-06-22 14:20:29.950502                39.432655             31.660505
# 2023-06-22 14:20:35.029907                40.503200             31.534071
# 2023-06-22 14:20:40.101851                41.316950             31.751280
#
#                             secundary_p014d1_bar  secundary_p015d1_bar  \
# date_time
# 2023-06-22 14:20:19.801173            124.348366              83.20528
# 2023-06-22 14:20:24.866509            123.735650              82.84218
# 2023-06-22 14:20:29.950502            123.894500              83.05777
# 2023-06-22 14:20:35.029907            123.792380              83.44356
# 2023-06-22 14:20:40.101851            123.849110              82.81949
#
#                             secundary_pa7b3_mm  secundary_pa4b2_c  \
# date_time
# 2023-06-22 14:20:19.801173           28.543823               99.9
# 2023-06-22 14:20:24.866509           28.478760               99.9
# 2023-06-22 14:20:29.950502           28.446167               99.9
# 2023-06-22 14:20:35.029907           28.283447              100.0
# 2023-06-22 14:20:40.101851           28.055603              100.0
#
#                             secundary_pa4b5_c  secundary_pu2b2_c  \
# date_time
# 2023-06-22 14:20:19.801173              103.2               99.9
# 2023-06-22 14:20:24.866509              103.2               99.8
# 2023-06-22 14:20:29.950502              103.2               99.9
# 2023-06-22 14:20:35.029907              103.3               99.9
# 2023-06-22 14:20:40.101851              103.3               99.9
#
#                             secundary_p012b3_c  secundary_p022b3_c  ...  \
# date_time                                                           ...
# 2023-06-22 14:20:19.801173                94.5               100.1  ...
# 2023-06-22 14:20:24.866509                94.6                99.8  ...
# 2023-06-22 14:20:29.950502                94.7                99.7  ...
# 2023-06-22 14:20:35.029907                94.8                99.9  ...
# 2023-06-22 14:20:40.101851                94.9               100.2  ...
#
#                             secundary_pumpspeed_rpm_lag_31  \
# date_time
# 2023-06-22 14:20:19.801173                       30.506277
# 2023-06-22 14:20:24.866509                       32.320232
# 2023-06-22 14:20:29.950502                       35.783356
# 2023-06-22 14:20:35.029907                       31.778254
# 2023-06-22 14:20:40.101851                       30.558435
#
#                             secundary_pumpspeed_rpm_lag_32  \
# date_time
# 2023-06-22 14:20:19.801173                       28.471409
# 2023-06-22 14:20:24.866509                       30.506277
# 2023-06-22 14:20:29.950502                       32.320232
# 2023-06-22 14:20:35.029907                       35.783356
# 2023-06-22 14:20:40.101851                       31.778254
#
#                             secundary_pumpspeed_rpm_lag_33  \
# date_time
# 2023-06-22 14:20:19.801173                       25.683084
# 2023-06-22 14:20:24.866509                       28.471409
# 2023-06-22 14:20:29.950502                       30.506277
# 2023-06-22 14:20:35.029907                       32.320232
# 2023-06-22 14:20:40.101851                       35.783356
#
#                             secundary_pumpspeed_rpm_lag_34  \
# date_time
# 2023-06-22 14:20:19.801173                       21.831861
# 2023-06-22 14:20:24.866509                       25.683084
# 2023-06-22 14:20:29.950502                       28.471409
# 2023-06-22 14:20:35.029907                       30.506277
# 2023-06-22 14:20:40.101851                       32.320232
#
#                             secundary_pumpspeed_rpm_lag_35  \
# date_time
# 2023-06-22 14:20:19.801173                       21.756290
# 2023-06-22 14:20:24.866509                       21.831861
# 2023-06-22 14:20:29.950502                       25.683084
# 2023-06-22 14:20:35.029907                       28.471409
# 2023-06-22 14:20:40.101851                       30.506277
#
#                             secundary_pumpspeed_rpm_lag_36  target_MEAN  \
# date_time
# 2023-06-22 14:20:19.801173                       21.749691    15.682200
# 2023-06-22 14:20:24.866509                       21.756290    15.731455
# 2023-06-22 14:20:29.950502                       21.831861    15.698088
# 2023-06-22 14:20:35.029907                       25.683084    15.601167
# 2023-06-22 14:20:40.101851                       28.471409    15.550323
#
#                             target_STD  target_MIN  target_MAX
# date_time
# 2023-06-22 14:20:19.801173    0.482931   15.062538    16.47346
# 2023-06-22 14:20:24.866509    0.442428   15.062538    16.47346
# 2023-06-22 14:20:29.950502    0.483945   14.986272    16.47346
# 2023-06-22 14:20:35.029907    0.521215   14.890940    16.47346
# 2023-06-22 14:20:40.101851    0.514921   14.890940    16.47346
#
# [5 rows x 486 columns]

# %% [markdown]
# ## Prueba ACF
# Utilizamos ACF para determinar si la serie tiene estacionalidad. El objetivo es analizar si presenta algun pico cada n pasos o si no presenta nada, determinamos que no tiene estacionalidad.

# %%
plot_acf(Y, lags = 60)
plt.show()

# %% [markdown]
# Los resultados muestran una tendencia descendente, concluyendo que la serie es no es estacionaria. Esto porque no tenemos picos en repetidos en intervalos fijos.

# %% [markdown]
# ## Prueba PACF
#
# Utilizamos PACF para determinar cuandos periodos pasados afectan el actual y asi definir la variable p en nuestro SARIMAX

# %%
plot_pacf(Y, lags = 60)
plt.show()

# %% [markdown]
# El PACF muestra coeficientes claramente significativos solo en los primeros rezagos (lag 1 y, en menor medida, lag 2), mientras que a partir del lag 3 las autocorrelaciones parciales son cercanas a cero.

# %% [markdown]
# ## Prueba de ADF
# Ejecutando la prueba ADF determinamos si la seria de tiempo es estacionaria o no

# %%
result = adfuller(Y.values)
print(f'ADF Statistic: {result[0]:.6f}')
print(f'p-value: {result[1]:.6f}')
print(f'Estacionaria: {result[1] <= 0.05}')
for key, value in result[4].items():
    print(f'{key}: {value:.3f}')

plt.plot(Y)
plt.show()
# Out:
# ADF Statistic: -28.625640
# p-value: 0.000000
# Estacionaria: True
# 1%: -3.430
# 5%: -2.862
# 10%: -2.567

# %% [markdown]
# Con estos resultados, podemos determinar que nuestra serie temporal es estacionaria, lo cual podemos definir el parámetro p en nuestro SARIMAX como 0

# %% [markdown]
# ## División del dataset en Train - Test
# Vamos a dividir el dataset en 80% Train y 20% Test, en este escenario en particular el orden de los datos si importa, no vamos a utilizar ningún algoritmo que nos haga un shuffle de los datos.
#
# Para esto vamos a utilizar el siguiente algoritmo:
# - https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html

# %%
print("Tamaño del dataset original: ", len(processed_dataset))

X_train, X_test, Y_train, Y_test = train_test_split(X, Y,
                                                    test_size = 0.2,
                                                    shuffle = False,
                                                    random_state = 42)


print("\nTamaño del train: ", len(X_train))
print("\nTamaño del test: ", len(X_test))
# Out:
# Tamaño del dataset original:  375852
#
# Tamaño del train:  300681
#
# Tamaño del test:  75171

# %% [markdown]
# ## Escalamiento de datos

# %%
# Escalado de características
transformer = RobustScaler().fit(X_train)
X_train_scaled = transformer.transform(X_train)
X_test_scaled = transformer.transform(X_test)

# %% [markdown]
# ## Comparación de Modelos
#
# Vamos a entrenar múltiples modelos para encontrar el mejor desempeño:
# - **SARIMAX**: Series temporales con variables exógenas
# - **Random Forest**: Ensemble method no paramétrico
# - **Gradient Boosting**: Ensemble potente para regresión

# %%
# Función mejorada de cálculo de MAPE
def calculate_mape(y_true, y_pred):
    """Calcula MAPE evitando divisiones por cero"""
    mask = y_true != 0
    if mask.sum() == 0:
        return np.inf
    return (np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])).mean() * 100

# Función para crear un resumen de métricas
def create_metrics_summary(y_true, y_pred, model_name):
    """Crea un resumen de métricas para un modelo"""
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    mape = calculate_mape(y_true.values if hasattr(y_true, 'values') else y_true, 
                          y_pred.values if hasattr(y_pred, 'values') else y_pred)
    
    return {
        'Model': model_name,
        'RMSE': rmse,
        'MAE': mae,
        'R²': r2,
        'MAPE (%)': mape
    }

print("Funciones de evaluación definidas correctamente")
# Out:
# Funciones de evaluación definidas correctamente

# %%
endog_train = Y_train
endog_test = Y_test
exog_train = X_train_scaled
exog_test = X_test_scaled
seasonal_period = 1

print("=" * 80)
print("Buscando parámetros ARIMA óptimos...")
print("=" * 80)

auto_model = auto_arima(
    endog_train,
    X = exog_train,
    seasonal = False,
    m = seasonal_period,
    test='adf',
    max_p = 5, max_q = 5,
    d = None, D = None,
    max_d = 2,
    stepwise = True,
    trace = True,
    error_action = 'warn',
    suppress_warnings = True
)

order = auto_model.order
seasonal_order = auto_model.seasonal_order

print(f"Orden óptimo (p,d,q): {order}")
print(f"Orden estacional (P,D,Q,m): {seasonal_order}")
print(f"Resumen de auto arima: {auto_model.summary()}")

# %%
# Entrenar Modelo
model = SARIMAX(endog_train,
                exog = exog_train,
                order = (1, 0, 2), #order,
                seasonal_order = (0, 0, 0, 0), #seasonal_order,
                enforce_stationarity = False,
                enforce_invertibility = False)

model_fit = model.fit()

# Realizar forecast sobre el conjunto de test
n_steps = len(endog_test)
forecast_res = model_fit.get_forecast(steps = n_steps, exog = exog_test)
y_pred_sarimax = forecast_res.predicted_mean

# Métricas SARIMAX
sarimax_metrics = create_metrics_summary(endog_test, y_pred_sarimax, "SARIMAX")

print(f"\n{'Métrica':<15} {'Valor':>12}")
print("-" * 30)
for key, value in sarimax_metrics.items():
    if key != 'Model':
        if isinstance(value, float):
            print(f"{key:<15} {value:>12.4f}")
            
# Visualización SARIMAX
plt.figure(figsize=(14, 5))
plt.plot(endog_test.index, endog_test.values, label='Real', linewidth=2, alpha=0.7)
plt.plot(endog_test.index, y_pred_sarimax.values, label='SARIMAX Predicción', linewidth=2, alpha=0.7)
plt.title('SARIMAX: Valores Reales vs Predichos', fontsize=14, fontweight='bold')
plt.xlabel('Tiempo', fontsize=11)
plt.ylabel('secundary_multipressure_bar (bar)', fontsize=11)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Métrica                Valor
# ------------------------------
# RMSE                 42.5786
# MAE                  31.7985
# R²                  -17.7765
# MAPE (%)           2942.1543

# %%
# 2. RANDOM FOREST REGRESSOR
print("\n" + "=" * 80)
print("2. MODELO RANDOM FOREST")
print("=" * 80)

rf_base = RandomForestRegressor(
    random_state = 42,
    n_jobs = -1
)

# Definir espacio de búsqueda de hiperparámetros
param_dist = {
    "n_estimators": [100, 200, 400],
    "max_depth": [8, 12, 16],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["sqrt"]
}

# TimeSeriesSplit para respetar el orden temporal
tscv = TimeSeriesSplit(n_splits = 5)

print("\nBuscando mejores hiperparámetros para Random Forest...")
rf_search = RandomizedSearchCV(
    estimator = rf_base,
    param_distributions = param_dist,
    n_iter = 10,                 
    scoring = "r2",              
    cv = tscv,
    n_jobs = -1,
    verbose = 2,
    random_state = 42
)

# Ajuste solo con datos de entrenamiento
rf_search.fit(X_train_scaled, Y_train)

print("\nMejores hiperparámetros encontrados:")
print(rf_search.best_params_)

# Modelo final: mejor estimador encontrado
rf_model = rf_search.best_estimator_
# Out:
# ================================================================================
# 2. MODELO RANDOM FOREST
# ================================================================================
#
# Buscando mejores hiperparámetros para Random Forest...
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  32.0s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  51.7s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 1.1min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 1.1min
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 1.6min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 1.6min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 2.1min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.1min
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 2.1min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time= 2.3min
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 1.5min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  33.6s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.3min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 1.1min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 3.1min
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time= 3.7min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 1.6min
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 3.1min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 3.9min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.1min
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 1.6min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  59.9s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 4.8min
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 4.3min
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 2.7min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 1.9min
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 5.4min
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 1.6min
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 4.1min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  56.0s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 7.0min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 3.5min
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 5.3min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 1.9min
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 3.5min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  34.7s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 4.5min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 1.1min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 3.0min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 2.9min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 1.6min
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time= 6.8min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 1.8min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time= 2.0min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 3.2min
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time= 3.5min
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.8min
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 3.6min
# [CV] END max_depth=16, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 5.6min
#
# Mejores hiperparámetros encontrados:
# {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 8}

# %%
print("\nEntrenando Random Forest final con los mejores hiperparámetros...")
rf_model.fit(X_train_scaled, Y_train)

# Predicción sobre el conjunto de test
y_pred_rf = rf_model.predict(X_test_scaled)

# Métricas
rf_metrics = create_metrics_summary(Y_test, y_pred_rf, "Random Forest")

print(f"\n{'Métrica':<15} {'Valor':>12}")
print("-" * 30)
for key, value in rf_metrics.items():
    if key != 'Model':
        if isinstance(value, float):
            print(f"{key:<15} {value:>12.4f}")

# Importancia de variables (Top 15)
feature_importance_rf = pd.Series(
    rf_model.feature_importances_,
    index=X.columns
).sort_values(ascending=False).head(15)

plt.figure(figsize=(10, 6))
feature_importance_rf.plot(kind='barh', color='steelblue')
plt.title('Top 15 Features - Random Forest', fontsize=14, fontweight='bold')
plt.xlabel('Importancia', fontsize=11)
plt.ylabel('Feature', fontsize=11)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# Visualización serie real vs predicción
plt.figure(figsize=(14, 5))
plt.plot(Y_test.index, Y_test.values, label='Real', linewidth=2, alpha=0.7)
plt.plot(Y_test.index, y_pred_rf, label='RF Predicción', linewidth=2, alpha=0.7)
plt.title('Random Forest: Valores Reales vs Predichos', fontsize=14, fontweight='bold')
plt.xlabel('Tiempo', fontsize=11)
plt.ylabel('secundary_multipressure_bar (bar)', fontsize=11)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Entrenando Random Forest final con los mejores hiperparámetros...
#
# Métrica                Valor
# ------------------------------
# RMSE                  5.2408
# MAE                   2.8482
# R²                    0.7155
# MAPE (%)            188.4061

# %%
print("\n" + "=" * 80)
print("3. MODELO GRADIENT BOOSTING")
print("=" * 80)

# Modelo base
gb_base = GradientBoostingRegressor(
    random_state = 42
)

# Espacio de búsqueda de hiperparámetros
gb_param_dist = {
    "n_estimators": [100, 200, 400],
    "learning_rate": [0.01, 0.05, 0.1],
    "max_depth": [3, 4, 6],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "subsample": [0.7, 0.8, 1.0],
    "max_features": ["sqrt"]
}

# TimeSeriesSplit para respetar la estructura temporal
tscv = TimeSeriesSplit(n_splits = 5)

print("\nBuscando mejores hiperparámetros para Gradient Boosting...")
gb_search = RandomizedSearchCV(
    estimator = gb_base,
    param_distributions = gb_param_dist,
    n_iter = 20,                
    scoring = "r2",
    cv = tscv,
    n_jobs = -1,
    verbose = 2,
    random_state = 42
)

gb_search.fit(X_train_scaled, Y_train)

print("\nMejores hiperparámetros encontrados (GB):")
print(gb_search.best_params_)

gb_model = gb_search.best_estimator_
# Out:
# ================================================================================
# 3. MODELO GRADIENT BOOSTING
# ================================================================================
#
# Buscando mejores hiperparámetros para Gradient Boosting...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END learning_rate=0.05, max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, subsample=0.7; total time=  25.8s
# [CV] END learning_rate=0.05, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, subsample=1.0; total time=  35.7s
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, subsample=0.8; total time=  38.6s
# [CV] END learning_rate=0.05, max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, subsample=0.7; total time=  51.2s
# [CV] END learning_rate=0.05, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, subsample=1.0; total time= 1.2min
# [CV] END learning_rate=0.05, max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, subsample=0.7; total time= 1.3min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, subsample=0.8; total time= 1.3min
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END learning_rate=0.05, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, subsample=0.8; total time=  38.9s
# [CV] END learning_rate=0.05, max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, subsample=0.7; total time= 1.7min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, subsample=0.8; total time= 2.0min
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, subsample=1.0; total time=  18.1s
# [CV] END learning_rate=0.05, max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100, subsample=0.7; total time= 2.2min
# [CV] END learning_rate=0.05, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, subsample=1.0; total time= 1.8min
# [CV] END learning_rate=0.05, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, subsample=0.8; total time= 1.3min
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, subsample=1.0; total time=  36.7s
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, subsample=0.8; total time= 2.6min
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, subsample=1.0; total time=  55.7s
# [CV] END learning_rate=0.05, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, subsample=1.0; total time= 2.4min
# [CV] END learning_rate=0.05, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, subsample=1.0; total time=  36.3s
# [CV] END learning_rate=0.05, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, subsample=0.8; total time= 2.0min
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, subsample=0.7; total time=  13.3s
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200, subsample=0.8; total time= 3.3min
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, subsample=1.0; total time= 1.3min
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, subsample=0.7; total time=  27.2s
# [CV] END learning_rate=0.05, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, subsample=1.0; total time= 3.1min
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, subsample=1.0; total time= 1.6min
# [CV] END learning_rate=0.05, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, subsample=1.0; total time= 1.2min
# [CV] END learning_rate=0.05, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, subsample=0.8; total time= 2.7min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, subsample=0.7; total time=  18.1s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, subsample=0.7; total time=  41.8s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, subsample=0.7; total time=  55.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, subsample=0.7; total time=  35.8s
# [CV] END learning_rate=0.05, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, subsample=1.0; total time= 1.9min
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, subsample=0.7; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, subsample=0.7; total time=  54.5s
# [CV] END learning_rate=0.05, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200, subsample=0.8; total time= 3.4min
# [CV] END learning_rate=0.05, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, subsample=0.7; total time=  18.2s
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, subsample=0.7; total time= 1.2min
# [CV] END learning_rate=0.05, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, subsample=0.7; total time=  35.3s
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400, subsample=0.8; total time= 1.3min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100, subsample=0.7; total time= 1.5min
# [CV] END learning_rate=0.05, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, subsample=1.0; total time= 2.5min
# [CV] END learning_rate=0.05, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, subsample=1.0; total time=  24.4s
# [CV] END learning_rate=0.05, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, subsample=0.7; total time=  53.8s
# [CV] END learning_rate=0.05, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, subsample=0.7; total time= 1.2min
# [CV] END learning_rate=0.05, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, subsample=1.0; total time=  48.9s
# [CV] END learning_rate=0.05, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200, subsample=1.0; total time= 3.1min
# [CV] END learning_rate=0.05, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, subsample=0.7; total time= 1.5min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400, subsample=0.8; total time= 2.7min
# [CV] END learning_rate=0.05, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, subsample=1.0; total time= 1.2min
# [CV] END learning_rate=0.05, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, subsample=1.0; total time= 1.7min
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400, subsample=0.7; total time=  52.9s
# [CV] END learning_rate=0.05, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, subsample=1.0; total time= 2.1min
# [CV] END learning_rate=0.1, max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400, subsample=0.8; total time= 2.0min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400, subsample=0.8; total time= 4.0min
# [CV] END learning_rate=0.05, max_depth=6, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, subsample=0.8; total time=  30.3s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400, subsample=0.7; total time= 1.8min
# [CV] END learning_rate=0.05, max_depth=6, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, subsample=0.8; total time= 1.0min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400, subsample=0.8; total time= 5.4min
# [CV] END learning_rate=0.05, max_depth=6, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, subsample=0.8; total time= 1.5min
# [CV] END learning_rate=0.1, max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400, subsample=0.8; total time= 4.0min
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400, subsample=0.7; total time= 2.7min
# [CV] END learning_rate=0.05, max_depth=6, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, subsample=0.8; total time= 2.0min
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400, subsample=0.7; total time= 3.6min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400, subsample=0.8; total time= 6.7min
# [CV] END learning_rate=0.01, max_depth=6, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400, subsample=0.7; total time= 1.7min
# [CV] END learning_rate=0.05, max_depth=6, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100, subsample=0.8; total time= 2.5min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, subsample=1.0; total time=  49.1s
# [CV] END learning_rate=0.1, max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400, subsample=0.8; total time= 6.0min
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400, subsample=0.7; total time= 4.5min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, subsample=1.0; total time= 1.7min
# [CV] END learning_rate=0.05, max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, subsample=1.0; total time= 1.2min
# [CV] END learning_rate=0.01, max_depth=6, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400, subsample=0.7; total time= 3.5min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, subsample=1.0; total time= 2.5min
# [CV] END learning_rate=0.1, max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400, subsample=0.8; total time= 8.1min
# [CV] END learning_rate=0.05, max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, subsample=1.0; total time= 2.5min
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400, subsample=0.7; total time=  53.8s
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, subsample=1.0; total time= 3.3min
# [CV] END learning_rate=0.01, max_depth=6, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400, subsample=0.7; total time= 5.3min
# [CV] END learning_rate=0.1, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, subsample=1.0; total time=  25.4s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400, subsample=0.7; total time= 1.8min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200, subsample=1.0; total time= 4.2min
# [CV] END learning_rate=0.1, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, subsample=1.0; total time=  50.5s
# [CV] END learning_rate=0.05, max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, subsample=1.0; total time= 3.8min
# [CV] END learning_rate=0.1, max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400, subsample=0.8; total time=10.1min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, subsample=0.8; total time=  20.8s
# [CV] END learning_rate=0.01, max_depth=6, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400, subsample=0.7; total time= 7.1min
# [CV] END learning_rate=0.1, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, subsample=1.0; total time= 1.3min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, subsample=0.8; total time=  41.3s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400, subsample=0.7; total time= 2.8min
# [CV] END learning_rate=0.1, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, subsample=1.0; total time= 1.7min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, subsample=0.8; total time=  59.2s
# [CV] END learning_rate=0.05, max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, subsample=1.0; total time= 4.9min
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400, subsample=0.7; total time= 3.6min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, subsample=0.8; total time= 1.2min
# [CV] END learning_rate=0.1, max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100, subsample=1.0; total time= 2.0min
# [CV] END learning_rate=0.01, max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100, subsample=0.8; total time= 1.4min
# [CV] END learning_rate=0.01, max_depth=6, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400, subsample=0.7; total time= 8.5min
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400, subsample=0.7; total time= 4.1min
# [CV] END learning_rate=0.05, max_depth=6, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200, subsample=1.0; total time= 5.8min
#
# Mejores hiperparámetros encontrados (GB):
# {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 3, 'learning_rate': 0.1}

# %%
print("\nEntrenando Gradient Boosting final con los mejores hiperparámetros...")
gb_model.fit(X_train_scaled, Y_train)

y_pred_gb = gb_model.predict(X_test_scaled)

# Métricas
gb_metrics = create_metrics_summary(Y_test, y_pred_gb, "Gradient Boosting")

print(f"\n{'Métrica':<15} {'Valor':>12}")
print("-" * 30)
for key, value in gb_metrics.items():
    if key != 'Model':
        if isinstance(value, float):
            print(f"{key:<15} {value:>12.4f}")

# Importancia de variables (Top 15)
feature_importance_gb = pd.Series(
    gb_model.feature_importances_,
    index=X.columns
).sort_values(ascending=False).head(15)

plt.figure(figsize=(10, 6))
feature_importance_gb.plot(kind='barh', color='forestgreen')
plt.title('Top 15 Features - Gradient Boosting', fontsize=14, fontweight='bold')
plt.xlabel('Importancia', fontsize=11)
plt.ylabel('Feature', fontsize=11)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# Visualización serie real vs predicción
plt.figure(figsize=(14, 5))
plt.plot(Y_test.index, Y_test.values, label='Real', linewidth=2, alpha=0.7)
plt.plot(Y_test.index, y_pred_gb, label='GB Predicción', linewidth=2, alpha=0.7)
plt.title('Gradient Boosting: Valores Reales vs Predichos', fontsize=14, fontweight='bold')
plt.xlabel('Tiempo', fontsize=11)
plt.ylabel('secundary_multipressure_bar (bar)', fontsize=11)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Entrenando Gradient Boosting final con los mejores hiperparámetros...
#
# Métrica                Valor
# ------------------------------
# RMSE                  4.8161
# MAE                   2.2972
# R²                    0.7598
# MAPE (%)            105.7691

# %% [markdown]
# # Resultados

# %%
# COMPARACIÓN DE MODELOS
print("\n" + "=" * 80)
print("COMPARACIÓN GENERAL DE MODELOS")
print("=" * 80)

# Crear tabla comparativa
results_list = [sarimax_metrics, rf_metrics, gb_metrics]


results_df = pd.DataFrame(results_list)
print("\n")
print(results_df.to_string(index=False))

# Encontrar mejor modelo por cada métrica
print("\n" + "-" * 80)
print("MEJOR MODELO POR MÉTRICA:")
print("-" * 80)

metrics_cols = ['RMSE', 'MAE', 'R²', 'MAPE (%)']
for metric in metrics_cols:
    if metric == 'R²':  # Maximizar R²
        best_idx = results_df[metric].idxmax()
    else:  # Minimizar otros
        best_idx = results_df[metric].idxmin()
    
    best_model = results_df.loc[best_idx, 'Model']
    best_value = results_df.loc[best_idx, metric]
    print(f"{metric:<15}: {best_model:<20} = {best_value:.4f}")

# Visualización comparativa
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle('Comparación de Desempeño de Modelos', fontsize=16, fontweight='bold')

# RMSE
ax = axes[0, 0]
results_df.plot(x='Model', y='RMSE', kind='bar', ax=ax, color='steelblue', legend=False)
ax.set_title('RMSE (menor es mejor)', fontweight='bold')
ax.set_ylabel('RMSE')
ax.set_xlabel('')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right')

# MAE
ax = axes[0, 1]
results_df.plot(x='Model', y='MAE', kind='bar', ax=ax, color='forestgreen', legend=False)
ax.set_title('MAE (menor es mejor)', fontweight='bold')
ax.set_ylabel('MAE')
ax.set_xlabel('')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right')

# R²
ax = axes[1, 0]
results_df.plot(x='Model', y='R²', kind='bar', ax=ax, color='coral', legend=False)
ax.set_title('R² (mayor es mejor)', fontweight='bold')
ax.set_ylabel('R²')
ax.set_xlabel('')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right')

# MAPE
ax = axes[1, 1]
results_df.plot(x='Model', y='MAPE (%)', kind='bar', ax=ax, color='mediumpurple', legend=False)
ax.set_title('MAPE (menor es mejor)', fontweight='bold')
ax.set_ylabel('MAPE (%)')
ax.set_xlabel('')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right')

plt.tight_layout()
plt.show()
# Out:
# ================================================================================
# COMPARACIÓN GENERAL DE MODELOS
# ================================================================================
#
#
#             Model      RMSE       MAE         R²    MAPE (%)
#           SARIMAX 42.578553 31.798533 -17.776507 2942.154345
#     Random Forest  5.240786  2.848237   0.715537  188.406092
# Gradient Boosting  4.816072  2.297156   0.759775  105.769145
#
# --------------------------------------------------------------------------------
# MEJOR MODELO POR MÉTRICA:
# --------------------------------------------------------------------------------
# RMSE           : Gradient Boosting    = 4.8161
# MAE            : Gradient Boosting    = 2.2972
# R²             : Gradient Boosting    = 0.7598
# MAPE (%)       : Gradient Boosting    = 105.7691

# %%
# ANÁLISIS DE RESIDUOS - MEJOR MODELO
print("\n" + "=" * 80)
print("ANÁLISIS DE RESIDUOS")
print("=" * 80)

# Identificar mejor modelo por R²
best_r2_idx = results_df['R²'].idxmax()
best_model_name = results_df.loc[best_r2_idx, 'Model']

if best_model_name == 'SARIMAX':
    y_pred_best = y_pred_sarimax
    y_test_best = endog_test
    print(f"\nMejor modelo: {best_model_name} (R² = {results_df.loc[best_r2_idx, 'R²']:.4f})")
elif best_model_name == 'Random Forest':
    y_pred_best = y_pred_rf
    y_test_best = Y_test
    print(f"\nMejor modelo: {best_model_name} (R² = {results_df.loc[best_r2_idx, 'R²']:.4f})")
elif best_model_name == 'Gradient Boosting':
    y_pred_best = y_pred_gb
    y_test_best = Y_test
    print(f"\nMejor modelo: {best_model_name} (R² = {results_df.loc[best_r2_idx, 'R²']:.4f})")
else:  # XGBoost
    #y_pred_best = y_pred_xgb
    y_test_best = Y_test
    print(f"\nMejor modelo: {best_model_name} (R² = {results_df.loc[best_r2_idx, 'R²']:.4f})")

# Calcular residuos
residuos = y_test_best.values - y_pred_best if hasattr(y_test_best, 'values') else y_test_best - y_pred_best

# Análisis estadístico de residuos
print(f"\nEstadísticas de residuos:")
print(f"  Media: {residuos.mean():.6f}")
print(f"  Desv. Est.: {residuos.std():.6f}")
print(f"  Min: {residuos.min():.6f}")
print(f"  Max: {residuos.max():.6f}")

# Visualización de residuos
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle(f'Análisis de Residuos - {best_model_name}', fontsize=16, fontweight='bold')

# Residuos en el tiempo
ax = axes[0, 0]
ax.plot(residuos, linewidth=1, alpha=0.7)
ax.axhline(y=0, color='r', linestyle='--', linewidth=2)
ax.set_title('Residuos en el Tiempo')
ax.set_xlabel('Tiempo')
ax.set_ylabel('Residuo')
ax.grid(True, alpha=0.3)

# Histograma de residuos
ax = axes[0, 1]
ax.hist(residuos, bins=50, edgecolor='black', alpha=0.7)
ax.axvline(x=0, color='r', linestyle='--', linewidth=2)
ax.set_title('Distribución de Residuos')
ax.set_xlabel('Residuo')
ax.set_ylabel('Frecuencia')
ax.grid(True, alpha=0.3, axis='y')

# Q-Q plot
from scipy import stats
ax = axes[1, 0]
stats.probplot(residuos, dist="norm", plot=ax)
ax.set_title('Q-Q Plot (Normalidad)')
ax.grid(True, alpha=0.3)

# Residuos vs Predichos
ax = axes[1, 1]
ax.scatter(y_pred_best, residuos, alpha=0.5)
ax.axhline(y=0, color='r', linestyle='--', linewidth=2)
ax.set_title('Residuos vs Valores Predichos')
ax.set_xlabel('Valores Predichos')
ax.set_ylabel('Residuos')
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Test de normalidad Shapiro-Wilk
if len(residuos) <= 5000:
    from scipy.stats import shapiro
    stat, p_value = shapiro(residuos)
    print(f"\nTest Shapiro-Wilk (normalidad de residuos):")
    print(f"  Estadístico: {stat:.6f}")
    print(f"  p-value: {p_value:.6f}")
    print(f"  Resultado: {'Residuos son normales' if p_value > 0.05 else 'Residuos NO son normales'}")
# Out:
# ================================================================================
# ANÁLISIS DE RESIDUOS
# ================================================================================
#
# Mejor modelo: Gradient Boosting (R² = 0.7598)
#
# Estadísticas de residuos:
#   Media: -0.416652
#   Desv. Est.: 4.798015
#   Min: -35.480211
#   Max: 56.895749
